# %%
import os
os.chdir("..")
# !pwd
# Out:
# /home/andrew/Development/swapnet

# %%
from argparse import Namespace

# %%
opt = Namespace(model="texture", batch_size=4, crop_bounds=None, crop_size=128, load_size=128, shuffle_data=False, dataset="texture", dataroot="data/video_data/andrew", input_transforms="all", cloth_channels=19, texture_channels=3, num_workers=1, max_dataset_size=200)
opt
# Out:
# Namespace(batch_size=4, cloth_channels=19, crop_bounds=None, crop_size=128, dataroot='data/video_data/andrew', dataset='texture', input_transforms='all', load_size=128, max_dataset_size=200, model='texture', num_workers=1, shuffle_data=False, texture_channels=3)

# %%
from datasets import create_dataset
dataset = create_dataset(opt)
# Out:
# dataset [TextureDataset] was created

# %%
dataset

# %%
my_iter = iter(dataset)

# %%
# from modules.swapnet_modules import TextureModule

# model = TextureModule()

# for i, data in enumerate(dataset):
#     print("===",i, "===")
#     textures, rois, cloths, targets = data
#     print(textures.shape)
#     print(rois.shape)
#     print(cloths.shape)
#     print(targets.shape)
#     model(textures, rois, cloths).shape

# %%
textures, rois, cloths, targets = next(iter(dataset))

# %%
from util.decode_labels import decode_cloth_labels

# %%
from torchvision import transforms

im = transforms.ToPILImage()(textures[0]).convert("RGB")
im
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7F6CFF0C7630>

# %%
im.size
# Out:
# (128, 128)
